# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Train.csv')

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df.apply(lambda x: len(x.unique()))
# Out:
# Item_Identifier              1559
# Item_Weight                   416
# Item_Fat_Content                5
# Item_Visibility              7880
# Item_Type                      16
# Item_MRP                     5938
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     4
# Outlet_Location_Type            3
# Outlet_Type                     4
# Item_Outlet_Sales            3493
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
cat_col = []
for x in df.dtypes.index:
    if df.dtypes[x] == 'object':
        cat_col.append(x)
cat_col
# Out:
# ['Item_Identifier',
#  'Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Identifier',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
cat_col.remove('Item_Identifier')
cat_col.remove('Outlet_Identifier')
cat_col
# Out:
# ['Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
for col in cat_col:
    print(col)
    print(df[col].value_counts())
    print()
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64
#
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64
#
# Outlet_Size
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64
#
# Outlet_Location_Type
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64
#
# Outlet_Type
# Supermarket Type1    5577
# Grocery Store        1083
# ...

# %%
item_weight_mean = df.pivot_table(values = "Item_Weight", index = 'Item_Identifier')
item_weight_mean
# Out:
#                  Item_Weight
# Item_Identifier
# DRA12                 11.600
# DRA24                 19.350
# DRA59                  8.270
# DRB01                  7.390
# DRB13                  6.115
# ...                      ...
# NCZ30                  6.590
# NCZ41                 19.850
# NCZ42                 10.500
# NCZ53                  9.600
# NCZ54                 14.650
#
# [1555 rows x 1 columns]

# %%
miss_bool = df['Item_Weight'].isnull()
miss_bool
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Name: Item_Weight, Length: 8523, dtype: bool

# %%
for i, item in enumerate(df['Item_Identifier']):
    if miss_bool[i]:
        if item in item_weight_mean:
            df['Item_Weight'][i] = item_weight_mean.loc[item]['Item_Weight']
        else:
            df['Item_Weight'][i] = np.mean(df['Item_Weight'])

# %%
df['Item_Weight'].isnull().sum()
# Out:
# 0

# %%
outlet_size_mode = df.pivot_table(values='Outlet_Size', columns='Outlet_Type', aggfunc=(lambda x: x.mode()[0]))
outlet_size_mode
# Out:
# Outlet_Type Grocery Store Supermarket Type1 Supermarket Type2  \
# Outlet_Size         Small             Small            Medium
#
# Outlet_Type Supermarket Type3
# Outlet_Size            Medium

# %%
miss_bool = df['Outlet_Size'].isnull()
df.loc[miss_bool, 'Outlet_Size'] = df.loc[miss_bool, 'Outlet_Type'].apply(lambda x: outlet_size_mode[x])

# %%
df['Outlet_Size'].isnull().sum()
# Out:
# 0

# %%
sum(df['Item_Visibility']==0)
# Out:
# 526

# %%
df.loc[:, 'Item_Visibility'].replace([0], [df['Item_Visibility'].mean()], inplace=True)

# %%
sum(df['Item_Visibility']==0)
# Out:
# 0

# %%
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace({'LF':'Low Fat', 'reg':'Regular', 'low fat':'Low Fat'})
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
df['New_Item_Type'] = df['Item_Identifier'].apply(lambda x: x[:2])
df['New_Item_Type']
# Out:
# 0       FD
# 1       DR
# 2       FD
# 3       FD
# 4       NC
#         ..
# 8518    FD
# 8519    FD
# 8520    NC
# 8521    FD
# 8522    DR
# Name: New_Item_Type, Length: 8523, dtype: object

# %%
df['New_Item_Type'] = df['New_Item_Type'].map({'FD':'Food', 'NC':'Non-Consumable', 'DR':'Drinks'})
df['New_Item_Type'].value_counts()
# Out:
# Food              6125
# Non-Consumable    1599
# Drinks             799
# Name: New_Item_Type, dtype: int64

# %%
df.loc[df['New_Item_Type']=='Non-Consumable', 'Item_Fat_Content'] = 'Non-Edible'
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat       3918
# Regular       3006
# Non-Edible    1599
# Name: Item_Fat_Content, dtype: int64

# %%
df['Outlet_Size'].value_counts()
# Out:
# Small     4798
# Medium    2793
# High       932
# Name: Outlet_Size, dtype: int64

# %%
df['Outlet_Years'] = 2013 - df['Outlet_Establishment_Year']

# %%
df['Outlet_Years']
# Out:
# 0       14
# 1        4
# 2       14
# 3       15
# 4       26
#         ..
# 8518    26
# 8519    11
# 8520     9
# 8521     4
# 8522    16
# Name: Outlet_Years, Length: 8523, dtype: int64

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.066132
# 4           NCD19         8.93       Non-Edible         0.066132
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
sns.distplot(df['Item_Weight'])
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='Density'>

# %%
sns.distplot(df['Item_Visibility'])
# Out:
# <AxesSubplot:xlabel='Item_Visibility', ylabel='Density'>

# %%
sns.distplot(df['Item_MRP'])
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Density'>

# %%
sns.distplot(df['Item_Outlet_Sales'])
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Density'>

# %%
df['Item_Outlet_Sales'] = np.log(1+df['Item_Outlet_Sales'])

# %%
sns.distplot(df['Item_Outlet_Sales'])
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Density'>

# %%
sns.countplot(df["Item_Fat_Content"])
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='count'>

# %%
l = list(df['Item_Type'].unique())
chart = sns.countplot(df["Item_Type"])
chart.set_xticklabels(labels=l, rotation=90)
# Out:
# [Text(0, 0, 'Dairy'),
#  Text(1, 0, 'Soft Drinks'),
#  Text(2, 0, 'Meat'),
#  Text(3, 0, 'Fruits and Vegetables'),
#  Text(4, 0, 'Household'),
#  Text(5, 0, 'Baking Goods'),
#  Text(6, 0, 'Snack Foods'),
#  Text(7, 0, 'Frozen Foods'),
#  Text(8, 0, 'Breakfast'),
#  Text(9, 0, 'Health and Hygiene'),
#  Text(10, 0, 'Hard Drinks'),
#  Text(11, 0, 'Canned'),
#  Text(12, 0, 'Breads'),
#  Text(13, 0, 'Starchy Foods'),
#  Text(14, 0, 'Others'),
#  Text(15, 0, 'Seafood')]

# %%
sns.countplot(df['Outlet_Establishment_Year'])
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year', ylabel='count'>

# %%
data=df['Item_MRP']
fig1, ax1 = plt.subplots()
ax1.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18bb74a0248>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18bb74b1f48>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18bb74adb48>],
#  'medians': [<matplotlib.lines.Line2D at 0x18bb74b8d48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18bb74b8d08>],
#  'means': []}

# %%
data=df['Outlet_Establishment_Year']
fig1, ax1 = plt.subplots()
ax1.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18bb750a808>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18bb751ec88>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18bb7516f48>],
#  'medians': [<matplotlib.lines.Line2D at 0x18bb7522a48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18bb7529848>],
#  'means': []}

# %%
sns.countplot(df['Outlet_Size'])
# Out:
# <AxesSubplot:xlabel='Outlet_Size', ylabel='count'>

# %%
sns.countplot(df['Outlet_Location_Type'])
# Out:
# <AxesSubplot:xlabel='Outlet_Location_Type', ylabel='count'>

# %%
sns.countplot(df['Outlet_Type'])
# Out:
# <AxesSubplot:xlabel='Outlet_Type', ylabel='count'>

# %%
corr = df.corr()
corr
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.017450  0.024756
# Item_Visibility              -0.017450         1.000000 -0.005259
# Item_MRP                      0.024756        -0.005259  1.000000
# Outlet_Establishment_Year    -0.008301        -0.078355  0.005020
# Item_Outlet_Sales             0.008059        -0.202466  0.509886
# Outlet_Years                  0.008301         0.078355 -0.005020
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales  \
# Item_Weight                                -0.008301           0.008059
# Item_Visibility                            -0.078355          -0.202466
# Item_MRP                                    0.005020           0.509886
# Outlet_Establishment_Year                   1.000000           0.077032
# Item_Outlet_Sales                           0.077032           1.000000
# ...

# %%
from pandas.plotting import scatter_matrix
attributes=["Item_Weight","Item_Visibility","Item_MRP","Outlet_Establishment_Year","Item_Outlet_Sales","Outlet_Years"]
scatter_matrix(df[attributes], figsize=(12,12))
# Out:
# array([[<AxesSubplot:xlabel='Item_Weight', ylabel='Item_Weight'>,
#         <AxesSubplot:xlabel='Item_Visibility', ylabel='Item_Weight'>,
#         <AxesSubplot:xlabel='Item_MRP', ylabel='Item_Weight'>,
#         <AxesSubplot:xlabel='Outlet_Establishment_Year', ylabel='Item_Weight'>,
#         <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Item_Weight'>,
#         <AxesSubplot:xlabel='Outlet_Years', ylabel='Item_Weight'>],
#        [<AxesSubplot:xlabel='Item_Weight', ylabel='Item_Visibility'>,
#         <AxesSubplot:xlabel='Item_Visibility', ylabel='Item_Visibility'>,
#         <AxesSubplot:xlabel='Item_MRP', ylabel='Item_Visibility'>,
#         <AxesSubplot:xlabel='Outlet_Establishment_Year', ylabel='Item_Visibility'>,
#         <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Item_Visibility'>,
#         <AxesSubplot:xlabel='Outlet_Years', ylabel='Item_Visibility'>],
#        [<AxesSubplot:xlabel='Item_Weight', ylabel='Item_MRP'>,
# ...

# %%
attributes=["Item_Weight","Item_Visibility","Item_MRP","Outlet_Establishment_Year","Item_Outlet_Sales","Outlet_Years"]
sns.pairplot(df[attributes])

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.066132
# 4           NCD19         8.93       Non-Edible         0.066132
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.plot.box(df['Item_Type'])  
plt.boxplot(df['Item_MRP']) 
plt.show()

# %%
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Outlet'] = le.fit_transform(df['Outlet_Identifier'])
cat_col = ['Item_Fat_Content', 'Item_Type', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type', 'New_Item_Type']
for col in cat_col:
    df[col] = le.fit_transform(df[col])
df.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0           FDA15         9.30                 0         0.016047          4
# 1           DRC01         5.92                 2         0.019278         14
# 2           FDN15        17.50                 0         0.016760         10
# 3           FDX07        19.20                 2         0.066132          6
# 4           NCD19         8.93                 1         0.066132          9
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092            OUT049                       1999            1
# 1   48.2692            OUT018                       2009            1
# 2  141.6180            OUT049                       1999            1
# 3  182.0950            OUT010                       1998            2
# 4   53.8614            OUT013                       1987            0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales  New_Item_Type  \
# ...

# %%
df = pd.get_dummies(df, columns=['Item_Fat_Content', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type', 'New_Item_Type'])
df.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Visibility  Item_Type  Item_MRP  \
# 0           FDA15         9.30         0.016047          4  249.8092
# 1           DRC01         5.92         0.019278         14   48.2692
# 2           FDN15        17.50         0.016760         10  141.6180
# 3           FDX07        19.20         0.066132          6  182.0950
# 4           NCD19         8.93         0.066132          9   53.8614
#
#   Outlet_Identifier  Outlet_Establishment_Year  Item_Outlet_Sales  \
# 0            OUT049                       1999           8.225808
# 1            OUT018                       2009           6.096776
# 2            OUT049                       1999           7.648868
# 3            OUT010                       1998           6.597664
# 4            OUT013                       1987           6.903451
#
#    Outlet_Years  Outlet  ...  Outlet_Location_Type_0  Outlet_Location_Type_1  \
# ...

# %%
X = df.drop(columns=['Outlet_Establishment_Year', 'Item_Identifier', 'Outlet_Identifier', 'Item_Outlet_Sales','Outlet_Type_0'])
y = df['Item_MRP']
X=df[['Item_Weight','Item_Visibility','Item_Type','Outlet_Years']]
X.head(1)
x1={'Item_Weight':[20.75],'Item_Visibility':[0.007564836],'Item_Type':[2],'Outlet_Years':[14]}
X1=pd.DataFrame(x1)
X1
df['Item_Outlet_Sales']
# Out:
# 0       8.225808
# 1       6.096776
# 2       7.648868
# 3       6.597664
# 4       6.903451
#           ...
# 8518    7.929984
# 8519    6.310436
# 8520    7.085159
# 8521    7.521100
# 8522    6.642056
# Name: Item_Outlet_Sales, Length: 8523, dtype: float64

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
def train(model, X, y):
    # train the model
    model.fit(X, y)
    # predict the training set
    pred = model.predict(X)
    pred1 = model.predict(X1)
    # perform cross-validation
    cv_score = cross_val_score(model, X, y, scoring='neg_mean_squared_error', cv=5)
    cv_score = np.abs(np.mean(cv_score))
    print(pred1)
    print("Model Report")
    print("MSE:",mean_squared_error(y,pred))
    print("CV Score:", cv_score)

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
model = LinearRegression(normalize=True)
train(model, X, y)
coef = pd.Series(model.coef_, X.columns).sort_values()
coef.plot(kind='bar', title="Model Coelrfficients")
# Out:
# [141.61192845]
# Model Report
# MSE: 3871.2473907184576
# CV Score: 3874.3722194831935
# <AxesSubplot:title={'center':'Model Coelrfficients'}>

# %%
X = df.drop(columns=['Outlet_Establishment_Year', 'Item_Identifier', 'Outlet_Identifier', 'Item_Outlet_Sales'])
y = df['Item_Outlet_Sales']

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
def train1(model, X, y):
    # train the model
    model.fit(X, y)
    # predict the training set
    pred = model.predict(X)
    # perform cross-validation
    cv_score = cross_val_score(model, X, y, scoring='neg_mean_squared_error', cv=5)
    cv_score = np.abs(np.mean(cv_score))
    print(pred)
    pred2=[];
    pred2=pred
    print("Model Report")
    print("MSE:",mean_squared_error(y,pred))
    print("CV Score:", cv_score)
    return pred2

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
model = LinearRegression(normalize=True)
lry=train1(model, X, y)
coef = pd.Series(model.coef_, X.columns).sort_values()
coef.plot(kind='bar', title="Model Coefficients")
# Out:
# [8.43359375 6.56640625 7.52734375 ... 7.09765625 7.01953125 6.93359375]
# Model Report
# MSE: 0.2880838937683423
# CV Score: 0.28921756014145145
# <AxesSubplot:title={'center':'Model Coefficients'}>

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
model = Ridge(normalize=True)
ry=train1(model, X, y)
coef = pd.Series(model.coef_, X.columns).sort_values()
coef.plot(kind='bar', title="Model Coefficients")
# Out:
# [8.07951819 6.96946411 7.64171896 ... 7.25279344 7.13388527 7.0072761 ]
# Model Report
# MSE: 0.42802985605683475
# CV Score: 0.4289289251562643
# <AxesSubplot:title={'center':'Model Coefficients'}>

# %%
model = Lasso()
ly=train1(model, X, y)
coef = pd.Series(model.coef_, X.columns).sort_values()
coef.plot(kind='bar', title="Model Coefficients")
# Out:
# [8.17430472 6.55103864 7.30289902 ... 6.84786582 6.99293043 6.77009821]
# Model Report
# MSE: 0.7628688679102087
# CV Score: 0.7630789166281843
# <AxesSubplot:title={'center':'Model Coefficients'}>

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
dty=train1(model, X, y)
coef = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind='bar', title="Feature Importance")
# Out:
# [8.22580774 6.09677636 7.64886847 ... 7.08515943 7.52110009 6.64205646]
# Model Report
# MSE: 2.7767015319289398e-34
# CV Score: 0.5826729873940517
# <AxesSubplot:title={'center':'Feature Importance'}>

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
rfy=train1(model, X, y)
coef = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind='bar', title="Feature Importance")
# Out:
# [8.31479174 6.24341236 7.57957369 ... 6.94327276 7.46382719 6.78807034]
# Model Report
# MSE: 0.04262914975987662
# CV Score: 0.3102028550809718
# <AxesSubplot:title={'center':'Feature Importance'}>

# %%
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
ety=train1(model, X, y)
coef = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind='bar', title="Feature Importance")
# Out:
# [8.22580774 6.09677636 7.64886847 ... 7.08515943 7.52110009 6.64205646]
# Model Report
# MSE: 1.0418489584965893e-28
# CV Score: 0.3323623163428349
# <AxesSubplot:title={'center':'Feature Importance'}>

# %%
from sklearn import model_selection
models = []
models.append(('LR', LinearRegression()))
models.append(('R', Ridge(normalize=True)))
models.append(('L', Lasso()))
models.append(('DR', DecisionTreeRegressor()))
models.append(('RFR', RandomForestRegressor()))
models.append(('ETR', ExtraTreesRegressor()))
# evaluate each model in turn
results = []
names = []
scoring = 'accuracy'
for name, model in models:
    kfold = model_selection.KFold()
    cv_results = model_selection.cross_val_score(model, X, y,scoring='neg_mean_squared_error', cv=5)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# boxplot algorithm comparison
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results,widths = 0.9, patch_artist = True)
ax.set_xticklabels(names)
plt.show()
# Out:
# LR: -0.289118 (0.006407)
# R: -0.428929 (0.011543)
# L: -0.763079 (0.029663)
# DR: -0.580368 (0.026061)
# RFR: -0.310823 (0.008232)
# ETR: -0.331541 (0.006755)

# %%
from pandas import DataFrame
attributes=["LinearRegression","Ridge","Lasso","DecisionTreeRegressor","RandomForestRegressor","ExtraTreesRegressor","Item_Outlet_Sales"]
lists=[lry,ry,ly,dty,rfy,ety]
df1 = DataFrame (lists).transpose()
df1.columns=["LinearRegression","Ridge","Lasso","DecisionTreeRegressor","RandomForestRegressor","ExtraTreesRegressor"]
df1=df1.join(y)
sns.pairplot(df1[attributes])

# %%
from pandas import DataFrame
attributes=["DecisionTreeRegressor","Item_Outlet_Sales"]
lists=[ety]
df1 = DataFrame (lists).transpose()
df1.columns=["DecisionTreeRegressor"]
df1=df1.join(y)
sns.pairplot(df1[attributes])
